# %% [markdown]
# **Implementation for Task 1 using sirs broilerplate code as a template**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
import tensorflow as tf  
import pandas as pd
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
import seaborn as sns
from sklearn.utils.multiclass import unique_labels
import sklearn

# %%
import os

# Load and preprocess the data
data = []  # List to store image data
labels = []  # List to store labels

# Define a function to extract the person label from the file name
def extract_person_label(file_name):
    return int(file_name.split('.')[0].replace('subject', '')) - 1  # Subtract 1 to make labels start from 0

# Load data and labels
# Assuming the dataset files are in the 'dataset' directory
dataset_dir = 'D:/FAST_NUCES/7thSemester/DLP/Assignment/Assignment1/Dataset/yale'

for file_name in os.listdir(dataset_dir):
    img = plt.imread(os.path.join(dataset_dir, file_name))
    # print(img.shape)
    data.append(img.flatten())  # Flatten image into a 1D array
    labels.append(extract_person_label(file_name))

data = np.array(data)
labels = np.array(labels)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
import random

# Randomly select four indices from the training dataset
train_indices = random.sample(range(len(X_train)), 4)

# Randomly select four indices from the testing dataset
test_indices = random.sample(range(len(X_test)), 4)

# Function to display images
def display_images(images, labels, title):
    plt.figure(figsize=(12, 3))
    plt.suptitle(title)
    for i, (image, label) in enumerate(zip(images, labels), 1):
        plt.subplot(1, 4, i)
        plt.imshow(image.reshape((243, 320)), cmap='gray')
        plt.title(f"Person {label}")
        plt.axis('off')
    plt.show()

# Display four random training images
train_images_to_display = X_train[train_indices]
train_labels_to_display = y_train[train_indices]
display_images(train_images_to_display, train_labels_to_display, "Random Training Images")

# Display four random testing images
test_images_to_display = X_test[test_indices]
test_labels_to_display = y_test[test_indices]
display_images(test_images_to_display, test_labels_to_display, "Random Testing Images")

# %% [markdown]
# **My Own Code Follows This Point Onwards**

# %%
# Define a function to create the MLP model
def create_mlp_model(hidden_layers, neurons_per_layer, activation_function):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(X_train.shape[1],)))

    for _ in range(hidden_layers): #reminder to self _ means we dont expect the variable itself to be used in the loop.
        model.add(tf.keras.layers.Dense(neurons_per_layer, activation=activation_function))

    model.add(tf.keras.layers.Dense(15, activation='softmax'))  # 15 output classes for 15 subjects
    
    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# Function to train and evaluate the MLP model
def train_evaluate_mlp(hidden_layers, neurons_per_layer, activation_function, epochs=100, batch_size=32):
    model = create_mlp_model(hidden_layers, neurons_per_layer, activation_function)
    
    
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2)
    
    # Test the model and calculate evaluation metrics
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    accuracy = accuracy_score(y_test, y_pred_classes)
    precision = precision_score(y_test, y_pred_classes, average='macro')
    recall = recall_score(y_test, y_pred_classes, average='macro')
    f1 = f1_score(y_test, y_pred_classes, average='macro')
    
    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1-score: {f1:.2f}')

    return accuracy, precision, recall, f1, history, y_pred_classes

# %%
# Experiment 2: With hyperparameter tuning (GridSearchCV)
param_grid = {
    'hidden_layers': [1, 2, 3],
    'neurons_per_layer': [32, 64, 128],
    'activation_function': ['relu', 'sigmoid']
}

# Create an instance of your MLP model
#mlp_model = create_mlp_model(hidden_layers=2, neurons_per_layer=64, activation_function='relu')
#Note to future self- making this instance does not force GridSearchCV to use these settings. It is just a template for the architecture you're using.
#instead it will use the param_grid to find the best settings.
#That didn't work but the logic behind my statements remains the same.

mlp_classifier = KerasClassifier(build_fn=create_mlp_model, epochs=100, batch_size=32) 


# Initialize GridSearchCV with the MLP model as the estimator
grid_search = GridSearchCV(estimator=mlp_classifier,
                           param_grid=param_grid,
                           scoring='accuracy',
                           cv=3)

# Fit the GridSearchCV object
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

accuracy2, precision2, recall2, f1_2, history2, y_pred2 = train_evaluate_mlp(**best_params, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# C:\Users\rahei\AppData\Local\Temp\ipykernel_18616\51442272.py:14: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   mlp_classifier = KerasClassifier(build_fn=create_mlp_model, epochs=100, batch_size=32)
# 3/3 [==============================] - 0s 6ms/step - loss: 7453.4185 - accuracy: 0.0341
# Epoch 2/100
# 3/3 [==============================] - 0s 9ms/step - loss: 377.0542 - accuracy: 0.0455
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7079 - accuracy: 0.0909
# Epoch 4/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7076 - accuracy: 0.0909
# Epoch 5/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7075 - accuracy: 0.0909
# Epoch 6/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7072 - accuracy: 0.0909
# Epoch 7/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7071 - accuracy: 0.0909
# Epoch 8/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7068 - accuracy: 0.0909
# Epoch 9/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7067 - accuracy: 0.0909
# Epoch 10/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7064 - accuracy: 0.0909
# Epoch 11/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7062 - accuracy: 0.0909
# Epoch 12/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7060 - accuracy: 0.0795
# Epoch 13/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7058 - accuracy: 0.0909
# Epoch 14/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7055 - accuracy: 0.0909
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7053 - accuracy: 0.0909
# Epoch 16/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7051 - accuracy: 0.0909
# Epoch 17/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7048 - accuracy: 0.0909
# Epoch 18/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7046 - accuracy: 0.0909
# Epoch 19/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7043 - accuracy: 0.0909
# Epoch 20/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7042 - accuracy: 0.0909
# Epoch 21/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7039 - accuracy: 0.0909
# Epoch 22/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7037 - accuracy: 0.0909
# Epoch 23/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7034 - accuracy: 0.0909
# Epoch 24/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7032 - accuracy: 0.0909
# Epoch 25/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7029 - accuracy: 0.0909
# Epoch 26/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7027 - accuracy: 0.0909
# Epoch 27/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7025 - accuracy: 0.0909
# Epoch 28/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7023 - accuracy: 0.0909
# Epoch 29/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7020 - accuracy: 0.0909
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7017 - accuracy: 0.0909
# Epoch 31/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7015 - accuracy: 0.0909
# Epoch 32/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7013 - accuracy: 0.0909
# Epoch 33/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7010 - accuracy: 0.0909
# Epoch 34/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7008 - accuracy: 0.0909
# Epoch 35/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7006 - accuracy: 0.0909
# Epoch 36/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7003 - accuracy: 0.0909
# Epoch 37/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7001 - accuracy: 0.0909
# Epoch 38/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6999 - accuracy: 0.0909
# Epoch 39/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6996 - accuracy: 0.0909
# Epoch 40/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6994 - accuracy: 0.0909
# Epoch 41/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6992 - accuracy: 0.0909
# Epoch 42/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6989 - accuracy: 0.0909
# Epoch 43/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6987 - accuracy: 0.0909
# Epoch 44/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6985 - accuracy: 0.0909
# Epoch 45/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6982 - accuracy: 0.0909
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6980 - accuracy: 0.0909
# Epoch 47/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6978 - accuracy: 0.0909
# Epoch 48/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6976 - accuracy: 0.0909
# Epoch 49/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6973 - accuracy: 0.0909
# Epoch 50/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6971 - accuracy: 0.0909
# Epoch 51/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6969 - accuracy: 0.0909
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6967 - accuracy: 0.0909
# Epoch 53/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6964 - accuracy: 0.0909
# Epoch 54/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6962 - accuracy: 0.0909
# Epoch 55/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6960 - accuracy: 0.0909
# Epoch 56/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6958 - accuracy: 0.0909
# Epoch 57/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6955 - accuracy: 0.0909
# Epoch 58/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6954 - accuracy: 0.0909
# Epoch 59/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6951 - accuracy: 0.0909
# Epoch 60/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6949 - accuracy: 0.0909
# Epoch 61/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6947 - accuracy: 0.0909
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6945 - accuracy: 0.0909
# Epoch 63/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6943 - accuracy: 0.0909
# Epoch 64/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6940 - accuracy: 0.0909
# Epoch 65/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6939 - accuracy: 0.0909
# Epoch 66/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6936 - accuracy: 0.0909
# Epoch 67/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6934 - accuracy: 0.0909
# Epoch 68/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6932 - accuracy: 0.0909
# Epoch 69/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6930 - accuracy: 0.0909
# Epoch 70/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6928 - accuracy: 0.0909
# Epoch 71/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6926 - accuracy: 0.0909
# Epoch 72/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6924 - accuracy: 0.0909
# Epoch 73/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6922 - accuracy: 0.0909
# Epoch 74/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6920 - accuracy: 0.0909
# Epoch 75/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6918 - accuracy: 0.0909
# Epoch 76/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6916 - accuracy: 0.0909
# Epoch 77/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6914 - accuracy: 0.0909
# Epoch 78/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6912 - accuracy: 0.0909
# Epoch 79/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6910 - accuracy: 0.0909
# Epoch 80/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6908 - accuracy: 0.0909
# Epoch 81/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6906 - accuracy: 0.0909
# Epoch 82/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6904 - accuracy: 0.0909
# Epoch 83/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6902 - accuracy: 0.0909
# Epoch 84/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6901 - accuracy: 0.0909
# Epoch 85/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6898 - accuracy: 0.0909
# Epoch 86/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6896 - accuracy: 0.0909
# Epoch 87/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6895 - accuracy: 0.0909
# Epoch 88/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6893 - accuracy: 0.0909
# Epoch 89/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6891 - accuracy: 0.0909
# Epoch 90/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6889 - accuracy: 0.0909
# Epoch 91/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6888 - accuracy: 0.0909
# Epoch 92/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6885 - accuracy: 0.0909
# Epoch 93/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6884 - accuracy: 0.0909
# Epoch 94/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6882 - accuracy: 0.0909
# Epoch 95/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.6880 - accuracy: 0.0909
# Epoch 96/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6878 - accuracy: 0.0909
# Epoch 97/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6877 - accuracy: 0.0909
# Epoch 98/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6875 - accuracy: 0.0909
# Epoch 99/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6873 - accuracy: 0.0909
# Epoch 100/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6871 - accuracy: 0.0909
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/100
# 3/3 [==============================] - 0s 8ms/step - loss: 6343.9404 - accuracy: 0.0227
# Epoch 2/100
# 3/3 [==============================] - 0s 9ms/step - loss: 5434.3911 - accuracy: 0.0455
# Epoch 3/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1445.5406 - accuracy: 0.0568
# Epoch 4/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7078 - accuracy: 0.0568
# Epoch 5/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7077 - accuracy: 0.0909
# Epoch 6/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7076 - accuracy: 0.0909
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7075 - accuracy: 0.0909
# Epoch 8/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7074 - accuracy: 0.0909
# Epoch 9/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7074 - accuracy: 0.0909
# Epoch 10/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7073 - accuracy: 0.0909
# Epoch 11/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7072 - accuracy: 0.0909
# Epoch 12/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7071 - accuracy: 0.0909
# Epoch 13/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7071 - accuracy: 0.0909
# Epoch 14/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7069 - accuracy: 0.0909
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7069 - accuracy: 0.0909
# Epoch 16/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7068 - accuracy: 0.0909
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7067 - accuracy: 0.0909
# Epoch 18/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7067 - accuracy: 0.0909
# Epoch 19/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7065 - accuracy: 0.0909
# Epoch 20/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7065 - accuracy: 0.0909
# Epoch 21/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7064 - accuracy: 0.0909
# Epoch 22/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7064 - accuracy: 0.0909
# Epoch 23/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7063 - accuracy: 0.0909
# Epoch 24/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7062 - accuracy: 0.0909
# Epoch 25/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7061 - accuracy: 0.0909
# Epoch 26/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7061 - accuracy: 0.0909
# Epoch 27/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7059 - accuracy: 0.0909
# Epoch 28/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7059 - accuracy: 0.0909
# Epoch 29/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7058 - accuracy: 0.0909
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7057 - accuracy: 0.0909
# Epoch 31/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7057 - accuracy: 0.0909
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7056 - accuracy: 0.0909
# Epoch 33/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7055 - accuracy: 0.0909
# Epoch 34/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7054 - accuracy: 0.0909
# Epoch 35/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7054 - accuracy: 0.0909
# Epoch 36/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7053 - accuracy: 0.0909
# Epoch 37/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7052 - accuracy: 0.0909
# Epoch 38/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7052 - accuracy: 0.0909
# Epoch 39/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7051 - accuracy: 0.0909
# Epoch 40/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7050 - accuracy: 0.0909
# Epoch 41/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7049 - accuracy: 0.0909
# Epoch 42/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7049 - accuracy: 0.0909
# Epoch 43/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7048 - accuracy: 0.0909
# Epoch 44/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7047 - accuracy: 0.0909
# Epoch 45/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7047 - accuracy: 0.0909
# Epoch 46/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7046 - accuracy: 0.0909
# Epoch 47/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7046 - accuracy: 0.0909
# Epoch 48/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7045 - accuracy: 0.0909
# Epoch 49/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7044 - accuracy: 0.0909
# Epoch 50/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7043 - accuracy: 0.0909
# Epoch 51/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7043 - accuracy: 0.0909
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7042 - accuracy: 0.0909
# Epoch 53/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7042 - accuracy: 0.0909
# Epoch 54/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7041 - accuracy: 0.0909
# Epoch 55/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7040 - accuracy: 0.0909
# Epoch 56/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7039 - accuracy: 0.0909
# Epoch 57/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7039 - accuracy: 0.0909
# Epoch 58/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7038 - accuracy: 0.0909
# Epoch 59/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7037 - accuracy: 0.0909
# Epoch 60/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7037 - accuracy: 0.0909
# Epoch 61/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7036 - accuracy: 0.0909
# Epoch 62/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7035 - accuracy: 0.0909
# Epoch 63/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7035 - accuracy: 0.0909
# Epoch 64/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7034 - accuracy: 0.0909
# Epoch 65/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7034 - accuracy: 0.0909
# Epoch 66/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7033 - accuracy: 0.0909
# Epoch 67/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7032 - accuracy: 0.0909
# Epoch 68/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7032 - accuracy: 0.0909
# Epoch 69/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7031 - accuracy: 0.0909
# Epoch 70/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7031 - accuracy: 0.0909
# Epoch 71/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7030 - accuracy: 0.0909
# Epoch 72/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7029 - accuracy: 0.0909
# Epoch 73/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7029 - accuracy: 0.0909
# Epoch 74/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7028 - accuracy: 0.0909
# Epoch 75/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7028 - accuracy: 0.0909
# Epoch 76/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7027 - accuracy: 0.0909
# Epoch 77/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7026 - accuracy: 0.0909
# Epoch 78/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7026 - accuracy: 0.0909
# Epoch 79/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7025 - accuracy: 0.0909
# Epoch 80/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7025 - accuracy: 0.0909
# Epoch 81/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7024 - accuracy: 0.0909
# Epoch 82/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7024 - accuracy: 0.0909
# Epoch 83/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7023 - accuracy: 0.0909
# Epoch 84/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7022 - accuracy: 0.0909
# Epoch 85/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7022 - accuracy: 0.0909
# Epoch 86/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7021 - accuracy: 0.0909
# Epoch 87/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7021 - accuracy: 0.0909
# Epoch 88/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7020 - accuracy: 0.0909
# Epoch 89/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7020 - accuracy: 0.0909
# Epoch 90/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7019 - accuracy: 0.0909
# Epoch 91/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7019 - accuracy: 0.0909
# Epoch 92/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7018 - accuracy: 0.0909
# Epoch 93/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7018 - accuracy: 0.0909
# Epoch 94/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7017 - accuracy: 0.0909
# Epoch 95/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7017 - accuracy: 0.0909
# Epoch 96/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7016 - accuracy: 0.0909
# Epoch 97/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7016 - accuracy: 0.0909
# Epoch 98/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7015 - accuracy: 0.0909
# Epoch 99/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7015 - accuracy: 0.0909
# Epoch 100/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7014 - accuracy: 0.0909
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/100
# 3/3 [==============================] - 0s 10ms/step - loss: 8414.9150 - accuracy: 0.0341
# Epoch 2/100
# 3/3 [==============================] - 0s 9ms/step - loss: 6362.9043 - accuracy: 0.1136
# Epoch 3/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2825.8589 - accuracy: 0.1364
# Epoch 4/100
# 3/3 [==============================] - 0s 9ms/step - loss: 730.4055 - accuracy: 0.0568
# Epoch 5/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7087 - accuracy: 0.0568
# Epoch 6/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7085 - accuracy: 0.0341
# Epoch 7/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7082 - accuracy: 0.0795
# Epoch 8/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7079 - accuracy: 0.0682
# Epoch 9/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7076 - accuracy: 0.0795
# Epoch 10/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7072 - accuracy: 0.0795
# Epoch 11/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7069 - accuracy: 0.0795
# Epoch 12/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7064 - accuracy: 0.0795
# Epoch 13/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7061 - accuracy: 0.0795
# Epoch 14/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7057 - accuracy: 0.0795
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7053 - accuracy: 0.0795
# Epoch 16/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7049 - accuracy: 0.0795
# Epoch 17/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7045 - accuracy: 0.0795
# Epoch 18/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.7041 - accuracy: 0.0795
# Epoch 19/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7037 - accuracy: 0.0795
# Epoch 20/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7033 - accuracy: 0.0795
# Epoch 21/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7029 - accuracy: 0.0795
# Epoch 22/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7025 - accuracy: 0.0795
# Epoch 23/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7021 - accuracy: 0.0795
# Epoch 24/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7017 - accuracy: 0.0795
# Epoch 25/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7012 - accuracy: 0.0795
# Epoch 26/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7008 - accuracy: 0.0795
# Epoch 27/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7005 - accuracy: 0.0795
# Epoch 28/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7001 - accuracy: 0.0795
# Epoch 29/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6997 - accuracy: 0.0795
# Epoch 30/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6993 - accuracy: 0.0795
# Epoch 31/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6989 - accuracy: 0.0795
# Epoch 32/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6984 - accuracy: 0.0795
# Epoch 33/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6981 - accuracy: 0.0795
# Epoch 34/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6977 - accuracy: 0.0795
# Epoch 35/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6973 - accuracy: 0.0795
# Epoch 36/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6969 - accuracy: 0.0795
# Epoch 37/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6965 - accuracy: 0.0795
# Epoch 38/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6961 - accuracy: 0.0795
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6957 - accuracy: 0.0795
# Epoch 40/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.6953 - accuracy: 0.0795
# Epoch 41/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6949 - accuracy: 0.0795
# Epoch 42/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6946 - accuracy: 0.0795
# Epoch 43/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6942 - accuracy: 0.0455
# Epoch 44/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6938 - accuracy: 0.0909
# Epoch 45/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6934 - accuracy: 0.0909
# Epoch 46/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6930 - accuracy: 0.0909
# Epoch 47/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6927 - accuracy: 0.1136
# Epoch 48/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6923 - accuracy: 0.1136
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6919 - accuracy: 0.1136
# Epoch 50/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6916 - accuracy: 0.1136
# Epoch 51/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.6911 - accuracy: 0.1136
# Epoch 52/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6908 - accuracy: 0.1136
# Epoch 53/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6904 - accuracy: 0.1136
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6901 - accuracy: 0.1136
# Epoch 55/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6897 - accuracy: 0.1136
# Epoch 56/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6894 - accuracy: 0.1136
# Epoch 57/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6890 - accuracy: 0.1136
# Epoch 58/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6887 - accuracy: 0.1136
# Epoch 59/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6883 - accuracy: 0.1136
# Epoch 60/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6879 - accuracy: 0.1136
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6876 - accuracy: 0.1136
# Epoch 62/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6872 - accuracy: 0.1136
# Epoch 63/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6869 - accuracy: 0.1136
# Epoch 64/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6866 - accuracy: 0.1136
# Epoch 65/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6863 - accuracy: 0.1136
# Epoch 66/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6859 - accuracy: 0.1136
# Epoch 67/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6856 - accuracy: 0.1136
# Epoch 68/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6853 - accuracy: 0.1136
# Epoch 69/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6849 - accuracy: 0.1136
# Epoch 70/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6846 - accuracy: 0.1136
# Epoch 71/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6843 - accuracy: 0.1136
# Epoch 72/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6839 - accuracy: 0.1136
# Epoch 73/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6836 - accuracy: 0.1136
# Epoch 74/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6832 - accuracy: 0.1136
# Epoch 75/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6830 - accuracy: 0.1136
# Epoch 76/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6826 - accuracy: 0.1136
# Epoch 77/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6822 - accuracy: 0.1136
# Epoch 78/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6819 - accuracy: 0.1136
# Epoch 79/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6817 - accuracy: 0.1136
# Epoch 80/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6813 - accuracy: 0.1136
# Epoch 81/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6810 - accuracy: 0.1136
# Epoch 82/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6807 - accuracy: 0.1136
# Epoch 83/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6803 - accuracy: 0.1136
# Epoch 84/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6800 - accuracy: 0.1136
# Epoch 85/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6797 - accuracy: 0.1136
# Epoch 86/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6794 - accuracy: 0.1136
# Epoch 87/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6791 - accuracy: 0.1136
# Epoch 88/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6788 - accuracy: 0.1136
# Epoch 89/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6785 - accuracy: 0.1136
# Epoch 90/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6782 - accuracy: 0.1136
# Epoch 91/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6779 - accuracy: 0.1136
# Epoch 92/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6777 - accuracy: 0.1136
# Epoch 93/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6773 - accuracy: 0.1136
# Epoch 94/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6770 - accuracy: 0.1136
# Epoch 95/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6767 - accuracy: 0.1136
# Epoch 96/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6764 - accuracy: 0.1136
# Epoch 97/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6761 - accuracy: 0.1136
# Epoch 98/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6759 - accuracy: 0.1136
# Epoch 99/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6755 - accuracy: 0.1136
# Epoch 100/100
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6753 - accuracy: 0.1136
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/100
# 3/3 [==============================] - 0s 14ms/step - loss: 11997.5146 - accuracy: 0.0568
# Epoch 2/100
# 3/3 [==============================] - 0s 16ms/step - loss: 10663.8281 - accuracy: 0.0909
# Epoch 3/100
# 3/3 [==============================] - 0s 16ms/step - loss: 5709.5425 - accuracy: 0.1023
# Epoch 4/100
# 3/3 [==============================] - 0s 15ms/step - loss: 3856.3491 - accuracy: 0.1364
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2627.3682 - accuracy: 0.1477
# Epoch 6/100
# 3/3 [==============================] - 0s 15ms/step - loss: 700.6816 - accuracy: 0.0682
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 13.5676 - accuracy: 0.0795
# Epoch 8/100
# 3/3 [==============================] - 0s 15ms/step - loss: 5.2349 - accuracy: 0.0795
# Epoch 9/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7064 - accuracy: 0.0795
# Epoch 10/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7062 - accuracy: 0.0795
# Epoch 11/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7061 - accuracy: 0.0795
# Epoch 12/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7059 - accuracy: 0.0795
# Epoch 13/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7057 - accuracy: 0.0795
# Epoch 14/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7056 - accuracy: 0.0795
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7054 - accuracy: 0.0795
# Epoch 16/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7053 - accuracy: 0.0795
# Epoch 17/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7051 - accuracy: 0.0909
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7049 - accuracy: 0.0909
# Epoch 19/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7047 - accuracy: 0.0909
# Epoch 20/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7046 - accuracy: 0.0909
# Epoch 21/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7044 - accuracy: 0.0909
# Epoch 22/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7043 - accuracy: 0.0909
# Epoch 23/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7041 - accuracy: 0.0909
# Epoch 24/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7039 - accuracy: 0.0909
# Epoch 25/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7037 - accuracy: 0.0909
# Epoch 26/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7035 - accuracy: 0.0909
# Epoch 27/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7034 - accuracy: 0.0909
# Epoch 28/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7032 - accuracy: 0.0909
# Epoch 29/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7030 - accuracy: 0.0909
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7028 - accuracy: 0.0909
# Epoch 31/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7026 - accuracy: 0.0909
# Epoch 32/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7025 - accuracy: 0.0909
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7023 - accuracy: 0.0909
# Epoch 34/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7021 - accuracy: 0.0909
# Epoch 35/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7019 - accuracy: 0.0909
# Epoch 36/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7017 - accuracy: 0.0909
# Epoch 37/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7015 - accuracy: 0.0909
# Epoch 38/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7013 - accuracy: 0.0909
# Epoch 39/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7011 - accuracy: 0.0909
# Epoch 40/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7010 - accuracy: 0.0909
# Epoch 41/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7008 - accuracy: 0.0909
# Epoch 42/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7006 - accuracy: 0.0909
# Epoch 43/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7004 - accuracy: 0.0909
# Epoch 44/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7002 - accuracy: 0.0909
# Epoch 45/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7000 - accuracy: 0.0909
# Epoch 46/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6998 - accuracy: 0.0909
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.6996 - accuracy: 0.0909
# Epoch 48/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6994 - accuracy: 0.0909
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6992 - accuracy: 0.0909
# Epoch 50/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6991 - accuracy: 0.0909
# Epoch 51/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6989 - accuracy: 0.0909
# Epoch 52/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6987 - accuracy: 0.0909
# Epoch 53/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6985 - accuracy: 0.0909
# Epoch 54/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6983 - accuracy: 0.0909
# Epoch 55/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6981 - accuracy: 0.0909
# Epoch 56/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6979 - accuracy: 0.0909
# Epoch 57/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6977 - accuracy: 0.0909
# Epoch 58/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6975 - accuracy: 0.0909
# Epoch 59/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6973 - accuracy: 0.0909
# Epoch 60/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2.6971 - accuracy: 0.0909
# Epoch 61/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6969 - accuracy: 0.0909
# Epoch 62/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6967 - accuracy: 0.0909
# Epoch 63/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6966 - accuracy: 0.0909
# Epoch 64/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6964 - accuracy: 0.0909
# Epoch 65/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6962 - accuracy: 0.0909
# Epoch 66/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2.6960 - accuracy: 0.0909
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6958 - accuracy: 0.0909
# Epoch 68/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6956 - accuracy: 0.0909
# Epoch 69/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6954 - accuracy: 0.0909
# Epoch 70/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6952 - accuracy: 0.0909
# Epoch 71/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6951 - accuracy: 0.0909
# Epoch 72/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.6948 - accuracy: 0.0909
# Epoch 73/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6946 - accuracy: 0.0909
# Epoch 74/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.6945 - accuracy: 0.0909
# Epoch 75/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6943 - accuracy: 0.0909
# Epoch 76/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6941 - accuracy: 0.0909
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6939 - accuracy: 0.0909
# Epoch 78/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6937 - accuracy: 0.0909
# Epoch 79/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6935 - accuracy: 0.0909
# Epoch 80/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6934 - accuracy: 0.0909
# Epoch 81/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6932 - accuracy: 0.0909
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6930 - accuracy: 0.0909
# Epoch 83/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6928 - accuracy: 0.0909
# Epoch 84/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6926 - accuracy: 0.0909
# Epoch 85/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6924 - accuracy: 0.0909
# Epoch 86/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6923 - accuracy: 0.0909
# Epoch 87/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6921 - accuracy: 0.0909
# Epoch 88/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6919 - accuracy: 0.0909
# Epoch 89/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6918 - accuracy: 0.0909
# Epoch 90/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6915 - accuracy: 0.0909
# Epoch 91/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6914 - accuracy: 0.0909
# Epoch 92/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6912 - accuracy: 0.0909
# Epoch 93/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6910 - accuracy: 0.0909
# Epoch 94/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6908 - accuracy: 0.0909
# Epoch 95/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6907 - accuracy: 0.0909
# Epoch 96/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6905 - accuracy: 0.0909
# Epoch 97/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6903 - accuracy: 0.0909
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6901 - accuracy: 0.0909
# Epoch 99/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6900 - accuracy: 0.0909
# Epoch 100/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6898 - accuracy: 0.0909
# 2/2 [==============================] - 0s 0s/step
# Epoch 1/100
# 3/3 [==============================] - 0s 15ms/step - loss: 10332.8037 - accuracy: 0.1477
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 17385.8262 - accuracy: 0.0682
# Epoch 3/100
# 3/3 [==============================] - 0s 15ms/step - loss: 19005.3203 - accuracy: 0.0795
# Epoch 4/100
# 3/3 [==============================] - 0s 16ms/step - loss: 12232.7646 - accuracy: 0.1136
# Epoch 5/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8423.5195 - accuracy: 0.1023
# Epoch 6/100
# 3/3 [==============================] - 0s 15ms/step - loss: 5475.8232 - accuracy: 0.1818
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 4138.1626 - accuracy: 0.1705
# Epoch 8/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1684.5801 - accuracy: 0.1705
# Epoch 9/100
# 3/3 [==============================] - 0s 16ms/step - loss: 276.7686 - accuracy: 0.1477
# Epoch 10/100
# 3/3 [==============================] - 0s 18ms/step - loss: 5.9666 - accuracy: 0.0682
# Epoch 11/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7082 - accuracy: 0.0682
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7081 - accuracy: 0.0682
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7081 - accuracy: 0.0682
# Epoch 14/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7081 - accuracy: 0.0682
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7080 - accuracy: 0.0682
# Epoch 16/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7080 - accuracy: 0.0682
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7079 - accuracy: 0.0682
# Epoch 18/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7078 - accuracy: 0.0682
# Epoch 19/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7078 - accuracy: 0.0682
# Epoch 20/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7077 - accuracy: 0.0682
# Epoch 21/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7077 - accuracy: 0.0682
# Epoch 22/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7076 - accuracy: 0.0682
# Epoch 23/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7076 - accuracy: 0.0682
# Epoch 24/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7075 - accuracy: 0.0682
# Epoch 25/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7074 - accuracy: 0.0682
# Epoch 26/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7074 - accuracy: 0.0682
# Epoch 27/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7073 - accuracy: 0.0682
# Epoch 28/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7073 - accuracy: 0.0682
# Epoch 29/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2.7072 - accuracy: 0.0682
# Epoch 30/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7071 - accuracy: 0.0682
# Epoch 31/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7071 - accuracy: 0.0682
# Epoch 32/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7070 - accuracy: 0.0682
# Epoch 33/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7070 - accuracy: 0.0682
# Epoch 34/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7069 - accuracy: 0.0682
# Epoch 35/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7068 - accuracy: 0.0682
# Epoch 36/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7068 - accuracy: 0.0682
# Epoch 37/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7067 - accuracy: 0.0682
# Epoch 38/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7066 - accuracy: 0.0682
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7066 - accuracy: 0.0682
# Epoch 40/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.7065 - accuracy: 0.0682
# Epoch 41/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7065 - accuracy: 0.0682
# Epoch 42/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7064 - accuracy: 0.0909
# Epoch 43/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7064 - accuracy: 0.0909
# Epoch 44/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7063 - accuracy: 0.0909
# Epoch 45/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7062 - accuracy: 0.0909
# Epoch 46/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7061 - accuracy: 0.0909
# Epoch 47/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7061 - accuracy: 0.0909
# Epoch 48/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7060 - accuracy: 0.0909
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7060 - accuracy: 0.0909
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.7059 - accuracy: 0.0909
# Epoch 51/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7058 - accuracy: 0.0909
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7058 - accuracy: 0.0909
# Epoch 53/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7057 - accuracy: 0.0909
# Epoch 54/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7056 - accuracy: 0.0909
# Epoch 55/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7056 - accuracy: 0.0909
# Epoch 56/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7055 - accuracy: 0.0909
# Epoch 57/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7054 - accuracy: 0.0909
# Epoch 58/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7054 - accuracy: 0.0909
# Epoch 59/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7053 - accuracy: 0.0909
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7053 - accuracy: 0.0909
# Epoch 61/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.7052 - accuracy: 0.0909
# Epoch 62/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7051 - accuracy: 0.0909
# Epoch 63/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7050 - accuracy: 0.0909
# Epoch 64/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.7050 - accuracy: 0.0909
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7049 - accuracy: 0.0909
# Epoch 66/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7048 - accuracy: 0.0909
# Epoch 67/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7048 - accuracy: 0.0909
# Epoch 68/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7047 - accuracy: 0.0909
# Epoch 69/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7047 - accuracy: 0.0909
# Epoch 70/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7046 - accuracy: 0.0909
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7045 - accuracy: 0.0909
# Epoch 72/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7045 - accuracy: 0.0909
# Epoch 73/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7044 - accuracy: 0.0909
# Epoch 74/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7044 - accuracy: 0.0909
# Epoch 75/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7043 - accuracy: 0.0909
# Epoch 76/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7043 - accuracy: 0.0909
# Epoch 77/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2.7042 - accuracy: 0.0909
# Epoch 78/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7041 - accuracy: 0.0909
# Epoch 79/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7041 - accuracy: 0.0909
# Epoch 80/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7040 - accuracy: 0.0909
# Epoch 81/100
# ...
# Epoch 92/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 1/100
# 4/4 [==============================] - 0s 65ms/step - loss: 8499.4883 - accuracy: 0.0952 - val_loss: 16463.5527 - val_accuracy: 0.0370
# Epoch 2/100
# 4/4 [==============================] - 0s 41ms/step - loss: 12279.7539 - accuracy: 0.1143 - val_loss: 15895.7979 - val_accuracy: 0.0370
# Epoch 3/100
# 4/4 [==============================] - 0s 39ms/step - loss: 12182.1699 - accuracy: 0.1333 - val_loss: 11238.5801 - val_accuracy: 0.1852
# Epoch 4/100
# 4/4 [==============================] - 0s 40ms/step - loss: 7336.3374 - accuracy: 0.1143 - val_loss: 7804.3066 - val_accuracy: 0.1481
# Epoch 5/100
# 4/4 [==============================] - 0s 41ms/step - loss: 4738.9888 - accuracy: 0.2286 - val_loss: 7076.7666 - val_accuracy: 0.1111
# Epoch 6/100
# 4/4 [==============================] - 0s 39ms/step - loss: 3774.4302 - accuracy: 0.2667 - val_loss: 4468.4380 - val_accuracy: 0.2222
# Epoch 7/100
# 4/4 [==============================] - 0s 39ms/step - loss: 2324.5493 - accuracy: 0.4000 - val_loss: 2974.1775 - val_accuracy: 0.3704
# Epoch 8/100
# 4/4 [==============================] - 0s 43ms/step - loss: 1174.4755 - accuracy: 0.4952 - val_loss: 1551.0813 - val_accuracy: 0.3333
# Epoch 9/100
# 4/4 [==============================] - 0s 39ms/step - loss: 903.6851 - accuracy: 0.4190 - val_loss: 959.4404 - val_accuracy: 0.4444
# Epoch 10/100
# 4/4 [==============================] - 0s 37ms/step - loss: 868.5148 - accuracy: 0.4286 - val_loss: 995.8841 - val_accuracy: 0.3333
# Epoch 11/100
# 4/4 [==============================] - 0s 39ms/step - loss: 446.2762 - accuracy: 0.5524 - val_loss: 1565.6842 - val_accuracy: 0.4444
# Epoch 12/100
# 4/4 [==============================] - 0s 38ms/step - loss: 538.6016 - accuracy: 0.6000 - val_loss: 1207.4386 - val_accuracy: 0.4444
# Epoch 13/100
# 4/4 [==============================] - 0s 39ms/step - loss: 384.6878 - accuracy: 0.5619 - val_loss: 997.3824 - val_accuracy: 0.6296
# Epoch 14/100
# 4/4 [==============================] - 0s 40ms/step - loss: 316.3248 - accuracy: 0.6667 - val_loss: 930.0762 - val_accuracy: 0.5556
# Epoch 15/100
# 4/4 [==============================] - 0s 36ms/step - loss: 265.7654 - accuracy: 0.6571 - val_loss: 333.7428 - val_accuracy: 0.5556
# Epoch 16/100
# 4/4 [==============================] - 0s 40ms/step - loss: 140.7047 - accuracy: 0.6667 - val_loss: 323.3132 - val_accuracy: 0.5556
# Epoch 17/100
# 4/4 [==============================] - 0s 40ms/step - loss: 115.3275 - accuracy: 0.7524 - val_loss: 170.2399 - val_accuracy: 0.6667
# Epoch 18/100
# 4/4 [==============================] - 0s 39ms/step - loss: 55.6480 - accuracy: 0.8000 - val_loss: 352.3589 - val_accuracy: 0.6296
# Epoch 19/100
# 4/4 [==============================] - 0s 40ms/step - loss: 117.1756 - accuracy: 0.8476 - val_loss: 215.6837 - val_accuracy: 0.7778
# Epoch 20/100
# 4/4 [==============================] - 0s 39ms/step - loss: 52.8021 - accuracy: 0.8762 - val_loss: 223.2701 - val_accuracy: 0.7407
# Epoch 21/100
# 4/4 [==============================] - 0s 39ms/step - loss: 104.6002 - accuracy: 0.8095 - val_loss: 185.2625 - val_accuracy: 0.7407
# Epoch 22/100
# 4/4 [==============================] - 0s 37ms/step - loss: 49.0522 - accuracy: 0.8286 - val_loss: 140.0896 - val_accuracy: 0.7407
# Epoch 23/100
# 4/4 [==============================] - 0s 39ms/step - loss: 77.3158 - accuracy: 0.8286 - val_loss: 351.0377 - val_accuracy: 0.5926
# Epoch 24/100
# 4/4 [==============================] - 0s 39ms/step - loss: 101.9398 - accuracy: 0.8095 - val_loss: 441.7478 - val_accuracy: 0.5926
# Epoch 25/100
# 4/4 [==============================] - 0s 39ms/step - loss: 49.1829 - accuracy: 0.8762 - val_loss: 410.8100 - val_accuracy: 0.7037
# Epoch 26/100
# 4/4 [==============================] - 0s 36ms/step - loss: 93.9705 - accuracy: 0.7905 - val_loss: 150.5641 - val_accuracy: 0.8148
# Epoch 27/100
# 4/4 [==============================] - 0s 40ms/step - loss: 17.2863 - accuracy: 0.9333 - val_loss: 186.4975 - val_accuracy: 0.7407
# Epoch 28/100
# 4/4 [==============================] - 0s 42ms/step - loss: 17.8382 - accuracy: 0.9143 - val_loss: 207.7025 - val_accuracy: 0.7407
# Epoch 29/100
# 4/4 [==============================] - 0s 39ms/step - loss: 18.2844 - accuracy: 0.9333 - val_loss: 284.8022 - val_accuracy: 0.6667
# Epoch 30/100
# 4/4 [==============================] - 0s 41ms/step - loss: 11.8394 - accuracy: 0.9429 - val_loss: 213.8035 - val_accuracy: 0.7037
# Epoch 31/100
# 4/4 [==============================] - 0s 37ms/step - loss: 10.0828 - accuracy: 0.9619 - val_loss: 184.5979 - val_accuracy: 0.7407
# Epoch 32/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.2464 - accuracy: 0.9714 - val_loss: 140.5108 - val_accuracy: 0.7778
# Epoch 33/100
# 4/4 [==============================] - 0s 38ms/step - loss: 3.1133 - accuracy: 0.9810 - val_loss: 77.1911 - val_accuracy: 0.7778
# Epoch 34/100
# 4/4 [==============================] - 0s 38ms/step - loss: 2.5135 - accuracy: 0.9810 - val_loss: 96.1732 - val_accuracy: 0.7778
# Epoch 35/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 180.7037 - val_accuracy: 0.7407
# Epoch 36/100
# 4/4 [==============================] - 0s 39ms/step - loss: 1.6733 - accuracy: 0.9810 - val_loss: 141.6422 - val_accuracy: 0.7778
# Epoch 37/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1157 - accuracy: 0.9905 - val_loss: 130.1659 - val_accuracy: 0.8889
# Epoch 38/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 132.0486 - val_accuracy: 0.8889
# Epoch 39/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 133.0002 - val_accuracy: 0.8889
# Epoch 40/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 133.5873 - val_accuracy: 0.8889
# Epoch 41/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 135.4248 - val_accuracy: 0.8519
# Epoch 42/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 137.0484 - val_accuracy: 0.8519
# Epoch 43/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.1362 - val_accuracy: 0.8519
# Epoch 44/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.9466 - val_accuracy: 0.8148
# Epoch 45/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 139.5123 - val_accuracy: 0.8148
# Epoch 46/100
# 4/4 [==============================] - 0s 38ms/step - loss: 1.5554e-07 - accuracy: 1.0000 - val_loss: 139.8883 - val_accuracy: 0.8148
# Epoch 47/100
# 4/4 [==============================] - 0s 39ms/step - loss: 8.6847e-06 - accuracy: 1.0000 - val_loss: 140.1198 - val_accuracy: 0.8148
# Epoch 48/100
# 4/4 [==============================] - 0s 40ms/step - loss: 5.4422e-04 - accuracy: 1.0000 - val_loss: 138.9286 - val_accuracy: 0.8148
# Epoch 49/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 138.1376 - val_accuracy: 0.8148
# Epoch 50/100
# 4/4 [==============================] - 0s 36ms/step - loss: 2.2706e-07 - accuracy: 1.0000 - val_loss: 137.6089 - val_accuracy: 0.8148
# Epoch 51/100
# 4/4 [==============================] - 0s 40ms/step - loss: 2.2624e-06 - accuracy: 1.0000 - val_loss: 137.2558 - val_accuracy: 0.8148
# Epoch 52/100
# 4/4 [==============================] - 0s 36ms/step - loss: 6.6983e-06 - accuracy: 1.0000 - val_loss: 137.0101 - val_accuracy: 0.8148
# Epoch 53/100
# 4/4 [==============================] - 0s 36ms/step - loss: 2.0024e-05 - accuracy: 1.0000 - val_loss: 136.8183 - val_accuracy: 0.8148
# Epoch 54/100
# 4/4 [==============================] - 0s 37ms/step - loss: 7.4687e-06 - accuracy: 1.0000 - val_loss: 136.6827 - val_accuracy: 0.8148
# Epoch 55/100
# 4/4 [==============================] - 0s 41ms/step - loss: 2.0627e-06 - accuracy: 1.0000 - val_loss: 136.5890 - val_accuracy: 0.8148
# Epoch 56/100
# 4/4 [==============================] - 0s 39ms/step - loss: 1.0887e-06 - accuracy: 1.0000 - val_loss: 136.5239 - val_accuracy: 0.8148
# Epoch 57/100
# 4/4 [==============================] - 0s 39ms/step - loss: 4.8250e-07 - accuracy: 1.0000 - val_loss: 136.4801 - val_accuracy: 0.8148
# Epoch 58/100
# 4/4 [==============================] - 0s 36ms/step - loss: 2.8383e-07 - accuracy: 1.0000 - val_loss: 136.4506 - val_accuracy: 0.8148
# Epoch 59/100
# 4/4 [==============================] - 0s 40ms/step - loss: 2.3387e-07 - accuracy: 1.0000 - val_loss: 136.4296 - val_accuracy: 0.8148
# Epoch 60/100
# 4/4 [==============================] - 0s 41ms/step - loss: 1.8392e-07 - accuracy: 1.0000 - val_loss: 136.4154 - val_accuracy: 0.8148
# Epoch 61/100
# 4/4 [==============================] - 0s 38ms/step - loss: 1.3283e-07 - accuracy: 1.0000 - val_loss: 136.4059 - val_accuracy: 0.8148
# Epoch 62/100
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1921e-07 - accuracy: 1.0000 - val_loss: 136.3996 - val_accuracy: 0.8148
# Epoch 63/100
# 4/4 [==============================] - 0s 39ms/step - loss: 1.0786e-07 - accuracy: 1.0000 - val_loss: 136.3954 - val_accuracy: 0.8148
# Epoch 64/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.0104e-07 - accuracy: 1.0000 - val_loss: 136.3923 - val_accuracy: 0.8148
# Epoch 65/100
# 4/4 [==============================] - 0s 39ms/step - loss: 9.5367e-08 - accuracy: 1.0000 - val_loss: 136.3902 - val_accuracy: 0.8148
# Epoch 66/100
# 4/4 [==============================] - 0s 38ms/step - loss: 8.8555e-08 - accuracy: 1.0000 - val_loss: 136.3888 - val_accuracy: 0.8148
# Epoch 67/100
# 4/4 [==============================] - 0s 40ms/step - loss: 8.6284e-08 - accuracy: 1.0000 - val_loss: 136.3878 - val_accuracy: 0.8148
# Epoch 68/100
# 4/4 [==============================] - 0s 40ms/step - loss: 8.5149e-08 - accuracy: 1.0000 - val_loss: 136.3869 - val_accuracy: 0.8148
# Epoch 69/100
# 4/4 [==============================] - 0s 39ms/step - loss: 8.2878e-08 - accuracy: 1.0000 - val_loss: 136.3864 - val_accuracy: 0.8148
# Epoch 70/100
# 4/4 [==============================] - 0s 41ms/step - loss: 8.0608e-08 - accuracy: 1.0000 - val_loss: 136.3853 - val_accuracy: 0.8148
# Epoch 71/100
# 4/4 [==============================] - 0s 39ms/step - loss: 7.9473e-08 - accuracy: 1.0000 - val_loss: 136.3848 - val_accuracy: 0.8148
# Epoch 72/100
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8337e-08 - accuracy: 1.0000 - val_loss: 136.3843 - val_accuracy: 0.8148
# Epoch 73/100
# 4/4 [==============================] - 0s 38ms/step - loss: 7.6067e-08 - accuracy: 1.0000 - val_loss: 136.3836 - val_accuracy: 0.8148
# Epoch 74/100
# 4/4 [==============================] - 0s 39ms/step - loss: 7.6067e-08 - accuracy: 1.0000 - val_loss: 136.3836 - val_accuracy: 0.8148
# Epoch 75/100
# 4/4 [==============================] - 0s 39ms/step - loss: 7.4931e-08 - accuracy: 1.0000 - val_loss: 136.3829 - val_accuracy: 0.8148
# Epoch 76/100
# 4/4 [==============================] - 0s 39ms/step - loss: 7.3796e-08 - accuracy: 1.0000 - val_loss: 136.3826 - val_accuracy: 0.8148
# Epoch 77/100
# 4/4 [==============================] - 0s 40ms/step - loss: 7.1525e-08 - accuracy: 1.0000 - val_loss: 136.3821 - val_accuracy: 0.8148
# Epoch 78/100
# 4/4 [==============================] - 0s 41ms/step - loss: 7.1525e-08 - accuracy: 1.0000 - val_loss: 136.3817 - val_accuracy: 0.8148
# Epoch 79/100
# 4/4 [==============================] - 0s 38ms/step - loss: 7.0390e-08 - accuracy: 1.0000 - val_loss: 136.3813 - val_accuracy: 0.8148
# Epoch 80/100
# 4/4 [==============================] - 0s 36ms/step - loss: 6.9255e-08 - accuracy: 1.0000 - val_loss: 136.3808 - val_accuracy: 0.8148
# Epoch 81/100
# 4/4 [==============================] - 0s 39ms/step - loss: 6.8119e-08 - accuracy: 1.0000 - val_loss: 136.3804 - val_accuracy: 0.8148
# Epoch 82/100
# 4/4 [==============================] - 0s 39ms/step - loss: 6.6984e-08 - accuracy: 1.0000 - val_loss: 136.3799 - val_accuracy: 0.8148
# Epoch 83/100
# 4/4 [==============================] - 0s 39ms/step - loss: 6.5849e-08 - accuracy: 1.0000 - val_loss: 136.3794 - val_accuracy: 0.8148
# Epoch 84/100
# 4/4 [==============================] - 0s 38ms/step - loss: 6.4713e-08 - accuracy: 1.0000 - val_loss: 136.3791 - val_accuracy: 0.8148
# Epoch 85/100
# 4/4 [==============================] - 0s 38ms/step - loss: 6.4713e-08 - accuracy: 1.0000 - val_loss: 136.3789 - val_accuracy: 0.8148
# Epoch 86/100
# 4/4 [==============================] - 0s 39ms/step - loss: 6.3578e-08 - accuracy: 1.0000 - val_loss: 136.3784 - val_accuracy: 0.8148
# Epoch 87/100
# 4/4 [==============================] - 0s 37ms/step - loss: 6.2443e-08 - accuracy: 1.0000 - val_loss: 136.3781 - val_accuracy: 0.8148
# Epoch 88/100
# 4/4 [==============================] - 0s 35ms/step - loss: 6.2443e-08 - accuracy: 1.0000 - val_loss: 136.3778 - val_accuracy: 0.8148
# Epoch 89/100
# 4/4 [==============================] - 0s 37ms/step - loss: 6.1307e-08 - accuracy: 1.0000 - val_loss: 136.3773 - val_accuracy: 0.8148
# Epoch 90/100
# 4/4 [==============================] - 0s 36ms/step - loss: 6.0172e-08 - accuracy: 1.0000 - val_loss: 136.3771 - val_accuracy: 0.8148
# Epoch 91/100
# 4/4 [==============================] - 0s 37ms/step - loss: 5.9037e-08 - accuracy: 1.0000 - val_loss: 136.3769 - val_accuracy: 0.8148
# Epoch 92/100
# 4/4 [==============================] - 0s 38ms/step - loss: 5.9037e-08 - accuracy: 1.0000 - val_loss: 136.3765 - val_accuracy: 0.8148
# Epoch 93/100
# 4/4 [==============================] - 0s 37ms/step - loss: 5.7901e-08 - accuracy: 1.0000 - val_loss: 136.3762 - val_accuracy: 0.8148
# Epoch 94/100
# 4/4 [==============================] - 0s 39ms/step - loss: 5.6766e-08 - accuracy: 1.0000 - val_loss: 136.3759 - val_accuracy: 0.8148
# Epoch 95/100
# 4/4 [==============================] - 0s 36ms/step - loss: 5.6766e-08 - accuracy: 1.0000 - val_loss: 136.3752 - val_accuracy: 0.8148
# Epoch 96/100
# 4/4 [==============================] - 0s 41ms/step - loss: 5.5631e-08 - accuracy: 1.0000 - val_loss: 136.3750 - val_accuracy: 0.8148
# Epoch 97/100
# 4/4 [==============================] - 0s 42ms/step - loss: 5.4496e-08 - accuracy: 1.0000 - val_loss: 136.3746 - val_accuracy: 0.8148
# Epoch 98/100
# 4/4 [==============================] - 0s 39ms/step - loss: 5.4496e-08 - accuracy: 1.0000 - val_loss: 136.3740 - val_accuracy: 0.8148
# Epoch 99/100
# 4/4 [==============================] - 0s 39ms/step - loss: 5.2225e-08 - accuracy: 1.0000 - val_loss: 136.3734 - val_accuracy: 0.8148
# Epoch 100/100
# 4/4 [==============================] - 0s 37ms/step - loss: 5.2225e-08 - accuracy: 1.0000 - val_loss: 136.3729 - val_accuracy: 0.8148
# 2/2 [==============================] - 0s 5ms/step
# Accuracy: 0.79
# Precision: 0.81
# Recall: 0.79
# F1-score: 0.77
# d:\Anaconda\ActualInstallation\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Running Model 1: User Defined Parameters
#Without hyperparameter tuning
accuracy1, precision1, recall1, f1_1, history1,y_pred1 = train_evaluate_mlp(hidden_layers=2, neurons_per_layer=64, activation_function='relu', epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 45ms/step - loss: 8433.3750 - accuracy: 0.0286 - val_loss: 17058.7949 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s 19ms/step - loss: 11163.2109 - accuracy: 0.0762 - val_loss: 8534.6494 - val_accuracy: 0.1481
# Epoch 3/100
# 4/4 [==============================] - 0s 22ms/step - loss: 6745.6641 - accuracy: 0.0857 - val_loss: 4564.4165 - val_accuracy: 0.1481
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 3595.7849 - accuracy: 0.1429 - val_loss: 4153.6255 - val_accuracy: 0.1111
# Epoch 5/100
# 4/4 [==============================] - 0s 21ms/step - loss: 2761.5425 - accuracy: 0.2000 - val_loss: 2226.2478 - val_accuracy: 0.2963
# Epoch 6/100
# 4/4 [==============================] - 0s 21ms/step - loss: 2072.2427 - accuracy: 0.2667 - val_loss: 1337.8818 - val_accuracy: 0.4074
# Epoch 7/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1187.9763 - accuracy: 0.3143 - val_loss: 1776.0568 - val_accuracy: 0.1111
# Epoch 8/100
# 4/4 [==============================] - 0s 22ms/step - loss: 1114.1411 - accuracy: 0.2476 - val_loss: 591.0650 - val_accuracy: 0.3704
# Epoch 9/100
# 4/4 [==============================] - 0s 21ms/step - loss: 378.7617 - accuracy: 0.4476 - val_loss: 809.9280 - val_accuracy: 0.2222
# Epoch 10/100
# 4/4 [==============================] - 0s 22ms/step - loss: 422.4995 - accuracy: 0.4762 - val_loss: 382.2851 - val_accuracy: 0.3704
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 218.6305 - accuracy: 0.5619 - val_loss: 441.2240 - val_accuracy: 0.4815
# Epoch 12/100
# 4/4 [==============================] - 0s 21ms/step - loss: 198.8126 - accuracy: 0.6286 - val_loss: 243.1440 - val_accuracy: 0.5185
# Epoch 13/100
# 4/4 [==============================] - 0s 21ms/step - loss: 167.5485 - accuracy: 0.6952 - val_loss: 445.7501 - val_accuracy: 0.3704
# Epoch 14/100
# 4/4 [==============================] - 0s 21ms/step - loss: 232.2087 - accuracy: 0.6667 - val_loss: 354.2875 - val_accuracy: 0.4815
# Epoch 15/100
# 4/4 [==============================] - 0s 22ms/step - loss: 169.1359 - accuracy: 0.6286 - val_loss: 217.9099 - val_accuracy: 0.6667
# Epoch 16/100
# 4/4 [==============================] - 0s 21ms/step - loss: 65.2068 - accuracy: 0.8095 - val_loss: 300.1640 - val_accuracy: 0.4074
# Epoch 17/100
# 4/4 [==============================] - 0s 22ms/step - loss: 48.9206 - accuracy: 0.7619 - val_loss: 64.2249 - val_accuracy: 0.7037
# Epoch 18/100
# 4/4 [==============================] - 0s 22ms/step - loss: 27.5864 - accuracy: 0.8190 - val_loss: 177.6972 - val_accuracy: 0.5556
# Epoch 19/100
# 4/4 [==============================] - 0s 22ms/step - loss: 35.1541 - accuracy: 0.8190 - val_loss: 108.3807 - val_accuracy: 0.5926
# Epoch 20/100
# 4/4 [==============================] - 0s 22ms/step - loss: 31.3771 - accuracy: 0.8286 - val_loss: 94.0202 - val_accuracy: 0.6296
# Epoch 21/100
# 4/4 [==============================] - 0s 22ms/step - loss: 5.7445 - accuracy: 0.9333 - val_loss: 55.5774 - val_accuracy: 0.8148
# Epoch 22/100
# 4/4 [==============================] - 0s 22ms/step - loss: 11.5150 - accuracy: 0.8952 - val_loss: 109.7840 - val_accuracy: 0.5926
# Epoch 23/100
# 4/4 [==============================] - 0s 22ms/step - loss: 13.2604 - accuracy: 0.8571 - val_loss: 54.0649 - val_accuracy: 0.7778
# Epoch 24/100
# 4/4 [==============================] - 0s 22ms/step - loss: 49.7778 - accuracy: 0.7524 - val_loss: 245.4869 - val_accuracy: 0.5926
# Epoch 25/100
# 4/4 [==============================] - 0s 22ms/step - loss: 54.2634 - accuracy: 0.7524 - val_loss: 205.2585 - val_accuracy: 0.3333
# Epoch 26/100
# 4/4 [==============================] - 0s 22ms/step - loss: 24.1835 - accuracy: 0.8095 - val_loss: 74.9420 - val_accuracy: 0.6667
# Epoch 27/100
# 4/4 [==============================] - 0s 24ms/step - loss: 45.0296 - accuracy: 0.7905 - val_loss: 318.5951 - val_accuracy: 0.4815
# Epoch 28/100
# 4/4 [==============================] - 0s 24ms/step - loss: 98.4370 - accuracy: 0.7143 - val_loss: 85.4688 - val_accuracy: 0.7037
# Epoch 29/100
# 4/4 [==============================] - 0s 19ms/step - loss: 94.0844 - accuracy: 0.6857 - val_loss: 441.1692 - val_accuracy: 0.2593
# Epoch 30/100
# 4/4 [==============================] - 0s 22ms/step - loss: 81.1706 - accuracy: 0.7429 - val_loss: 238.9181 - val_accuracy: 0.7037
# Epoch 31/100
# 4/4 [==============================] - 0s 21ms/step - loss: 61.5717 - accuracy: 0.7810 - val_loss: 109.8250 - val_accuracy: 0.6296
# Epoch 32/100
# 4/4 [==============================] - 0s 18ms/step - loss: 35.4328 - accuracy: 0.8000 - val_loss: 219.5507 - val_accuracy: 0.5926
# Epoch 33/100
# 4/4 [==============================] - 0s 18ms/step - loss: 29.9439 - accuracy: 0.8762 - val_loss: 70.0843 - val_accuracy: 0.7778
# Epoch 34/100
# 4/4 [==============================] - 0s 18ms/step - loss: 28.8234 - accuracy: 0.8190 - val_loss: 119.1937 - val_accuracy: 0.6667
# Epoch 35/100
# 4/4 [==============================] - 0s 18ms/step - loss: 25.0966 - accuracy: 0.8762 - val_loss: 197.2698 - val_accuracy: 0.7037
# Epoch 36/100
# 4/4 [==============================] - 0s 17ms/step - loss: 18.3244 - accuracy: 0.8857 - val_loss: 74.3339 - val_accuracy: 0.7778
# Epoch 37/100
# 4/4 [==============================] - 0s 22ms/step - loss: 23.0221 - accuracy: 0.8857 - val_loss: 166.9325 - val_accuracy: 0.4444
# Epoch 38/100
# 4/4 [==============================] - 0s 22ms/step - loss: 18.6294 - accuracy: 0.8667 - val_loss: 126.3073 - val_accuracy: 0.7037
# Epoch 39/100
# 4/4 [==============================] - 0s 21ms/step - loss: 8.7106 - accuracy: 0.9143 - val_loss: 78.0608 - val_accuracy: 0.8519
# Epoch 40/100
# 4/4 [==============================] - 0s 20ms/step - loss: 14.8987 - accuracy: 0.9238 - val_loss: 70.1868 - val_accuracy: 0.8519
# Epoch 41/100
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1641 - accuracy: 0.9524 - val_loss: 124.9035 - val_accuracy: 0.7778
# Epoch 42/100
# 4/4 [==============================] - 0s 21ms/step - loss: 3.9183 - accuracy: 0.9429 - val_loss: 197.9432 - val_accuracy: 0.5185
# Epoch 43/100
# 4/4 [==============================] - 0s 21ms/step - loss: 7.3241 - accuracy: 0.9143 - val_loss: 125.7938 - val_accuracy: 0.7407
# Epoch 44/100
# 4/4 [==============================] - 0s 19ms/step - loss: 7.0785 - accuracy: 0.9429 - val_loss: 99.5757 - val_accuracy: 0.7778
# Epoch 45/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1361 - accuracy: 0.9905 - val_loss: 92.5283 - val_accuracy: 0.7407
# Epoch 46/100
# 4/4 [==============================] - 0s 22ms/step - loss: 2.1395 - accuracy: 0.9810 - val_loss: 87.3741 - val_accuracy: 0.7778
# Epoch 47/100
# 4/4 [==============================] - 0s 22ms/step - loss: 7.6297e-04 - accuracy: 1.0000 - val_loss: 103.7686 - val_accuracy: 0.7778
# Epoch 48/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1180 - accuracy: 0.9905 - val_loss: 104.7042 - val_accuracy: 0.7778
# Epoch 49/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4424 - accuracy: 0.9905 - val_loss: 97.5202 - val_accuracy: 0.8148
# Epoch 50/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7117 - accuracy: 0.9810 - val_loss: 84.0030 - val_accuracy: 0.8148
# Epoch 51/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 103.3744 - val_accuracy: 0.7778
# Epoch 52/100
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0912 - accuracy: 0.9905 - val_loss: 113.3176 - val_accuracy: 0.7778
# Epoch 53/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5557 - accuracy: 0.9905 - val_loss: 96.2357 - val_accuracy: 0.7778
# Epoch 54/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 85.5786 - val_accuracy: 0.7778
# Epoch 55/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 79.0766 - val_accuracy: 0.8148
# Epoch 56/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 75.2697 - val_accuracy: 0.8148
# Epoch 57/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 72.7279 - val_accuracy: 0.8148
# Epoch 58/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 71.0434 - val_accuracy: 0.8148
# Epoch 59/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.9272 - val_accuracy: 0.8148
# Epoch 60/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 69.1591 - val_accuracy: 0.8148
# Epoch 61/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 68.6114 - val_accuracy: 0.8148
# Epoch 62/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 68.2487 - val_accuracy: 0.8148
# Epoch 63/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 68.0086 - val_accuracy: 0.8148
# Epoch 64/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.8496 - val_accuracy: 0.8148
# Epoch 65/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.7444 - val_accuracy: 0.8148
# Epoch 66/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.6746 - val_accuracy: 0.8148
# Epoch 67/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.6285 - val_accuracy: 0.8148
# Epoch 68/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5981 - val_accuracy: 0.8148
# Epoch 69/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5779 - val_accuracy: 0.8148
# Epoch 70/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5648 - val_accuracy: 0.8148
# Epoch 71/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5561 - val_accuracy: 0.8148
# Epoch 72/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5504 - val_accuracy: 0.8148
# Epoch 73/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5467 - val_accuracy: 0.8148
# Epoch 74/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5443 - val_accuracy: 0.8148
# Epoch 75/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5428 - val_accuracy: 0.8148
# Epoch 76/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5417 - val_accuracy: 0.8148
# Epoch 77/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5410 - val_accuracy: 0.8148
# Epoch 78/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5406 - val_accuracy: 0.8148
# Epoch 79/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5404 - val_accuracy: 0.8148
# Epoch 80/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5401 - val_accuracy: 0.8148
# Epoch 81/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5402 - val_accuracy: 0.8148
# Epoch 82/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5401 - val_accuracy: 0.8148
# Epoch 83/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 84/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 85/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 86/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 87/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 88/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 89/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 90/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 91/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 92/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 93/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 94/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 95/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 96/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 97/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 98/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 99/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# Epoch 100/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.5400 - val_accuracy: 0.8148
# 2/2 [==============================] - 0s 10ms/step
# Accuracy: 0.85
# Precision: 0.88
# Recall: 0.86
# F1-score: 0.84

# %% [markdown]
# **Below Are The Training Testing Loss Plots**

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Plot the training and validation loss of version 1 on the first subplot
ax1.plot(history1.history['loss'], label='Training Loss', color='blue')
ax1.plot(history1.history['val_loss'], label='Validation Loss', color='orange')
ax1.set_title("User Defined Version")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss")
ax1.legend()
ax1.grid(True)

# Set the x-axis ticks by increments of 1 for the first subplot
ax1.set_xticks(np.arange(min(history1.epoch), max(history1.epoch)+1, 1))
ax1.set_xticklabels(np.arange(min(history1.epoch), max(history1.epoch)+1, 1))

# Plot the training and validation loss of version 2 on the second subplot
ax2.plot(history2.history['loss'], label='Training Loss', color='blue')
ax2.plot(history2.history['val_loss'], label='Validation Loss', color='orange')
ax2.set_title("GridSearchCV Version")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Loss")
ax2.legend()
ax2.grid(True)

# Set the x-axis ticks by increments of 1 for the second subplot
ax2.set_xticks(np.arange(min(history2.epoch), max(history2.epoch)+1, 1))
ax2.set_xticklabels(np.arange(min(history2.epoch), max(history2.epoch)+1, 1))

# Adjust the spacing between the subplots
plt.tight_layout()

# Show the figure
plt.show()

# %% [markdown]
# **Below follows the Confusion Matrix Implementation**
#
# I ended up making a confusion matrix and then putting it into a heat map because I thought it would be easier to read.

# %%
#Writing Function for Confusion Matrix
def plot_conf_mat(y_test,y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted {label}' for label in labels]
    indexx = [f'Actual {label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_test,y_pred), columns=column, index=indexx)
    return sns.heatmap(table, annot=True, fmt='d', cmap='viridis')

plt.title('Confusion Matrix for GridSearchCV Model', fontsize=16, loc='center')
plot_conf_mat(y_test,y_pred2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18616\2893216754.py in <module>
#       8
#       9 plt.title('Confusion Matrix for GridSearchCV Model', fontsize=16, loc='center')
# ---> 10 plot_conf_mat(y_test,y_pred2)
#
# ~\AppData\Local\Temp\ipykernel_18616\2893216754.py in plot_conf_mat(y_test, y_pred)
#       4     column = [f'Predicted {label}' for label in labels]
#       5     indexx = [f'Actual {label}' for label in labels]
# ----> 6     table = pd.DataFrame(confusion_matrix(y_test,y_pred), columns=column, index=indexx)
#       7     return sns.heatmap(table, annot=True, fmt='d', cmap='viridis')
#       8
#
# d:\Anaconda\ActualInstallation\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                 )
#     693             else:
# --> 694                 mgr = ndarray_to_mgr(
#     695                     data,
#     696                     index,
#
# d:\Anaconda\ActualInstallation\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     349     )
#     350
# --> 351     _check_values_indices_shape_match(values, index, columns)
#     352
#     353     if typ == "array":
#
# d:\Anaconda\ActualInstallation\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     420         passed = values.shape
#     421         implied = (len(index), len(columns))
# --> 422         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     423
#     424
#
# ValueError: Shape of passed values is (15, 15), indices imply (14, 14)

# %%
plt.title('Confusion Matrix for User-Defined Model', fontsize=16, loc='center')
plot_conf_mat(y_test,y_pred1)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix for User-Defined Model'}>
